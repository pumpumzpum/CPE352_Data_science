# %% [markdown]
# # Data source : Video Game Sales
# ### Kaggle : https://www.kaggle.com/gregorut/videogamesales

# %% [markdown]
# ## Description of dataset
#  This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales. (in millions) gathered from NA_Sales, EU_Sales, JP_Sales, Other_Sales

# %%
# Data implement
import pandas as pd

## Visualize
import seaborn as sns

#Counting data
from collections import Counter

# %%
vgSalesData = pd.read_csv("D:/Pum_Program/HDS_WORK/Year 3/Semester 1/Data sci/Lab week3/datasource/vgsales.csv")

# %% [markdown]
# ## Identify form of data

# %% [markdown]
# ### Unit : the name of game  each platform

# %%
vgSalesData.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
vgSalesData.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
vgSalesData.sort_values(by="Year",ascending = False).head(15)
# Out:
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
# 8293    8295                      Shin Megami Tensei IV: Final      3DS
# 13647  13649                                     Hitman (2016)      PS4
# 13596  13598      Card Fight!! Vanguard G: Stride to Victory!!      3DS
# 13602  13604        Refrain no Chika Meikyuu to Majo no Ryodan      PSV
# 13614  13616                  Utawarerumono: Futari no Hakuoro      PS4
# 13620  13622                 Kamen Rider: Battride War Genesis      PS3
# 4658    4660                                   Hyrule Warriors      3DS
# 13650  13652                                     7 Days to Die     XOne
# ...

# %% [markdown]
# ### In my opinion,
# ### The Imagine : Makeup Artist game, Phantasy Star online2 and The Brothers Conflict
# ### are abnomal from the other unit or maybe outlier
# ### (The dataset was updated in 2016)
#
# ## CHECK IT
# #### Makeup Artist : https://english-otome-games.fandom.com/wiki/Imagine:_Makeup_Artist
# ### the game was released in 2009
#
# #### Phantasy Star online2 Episode 4 : Deluxe Package :https://www.bumped.org/psublog/pso2-episode-4-deluxe-package/
# ### the game was released in  2016 (PS4 and PSV)
#
# #### Brothers Conflict : Precious Baby : https://www.play-asia.com/brothers-conflict-precious-baby-for-nintendo-switch-limited-edit/13/70cqnn
# ### the game was release in 2016 (PS vista)

# %%
vgSalesData["Year"] = vgSalesData["Year"].replace(2020.0,2009.0) # Fix it
vgSalesData["Year"] = vgSalesData["Year"].replace(2017.0,2016.0)

# %%
vgSalesData.sort_values(by="Year",ascending = False).head(5)
# Out:
#         Rank                                       Name Platform    Year  \
# 8293    8295               Shin Megami Tensei IV: Final      3DS  2016.0
# 16344  16347                  Cities: Skylines Snowfall       PC  2016.0
# 4513    4515                                  Minecraft     WiiU  2016.0
# 13789  13791  Star Ocean 5: Integrity and Faithlessness      PS3  2016.0
# 13763  13765                   One Piece: Burning Blood     XOne  2016.0
#
#               Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 8293   Role-Playing             Deep Silver      0.03      0.00      0.14
# 16344    Simulation     Paradox Development      0.00      0.01      0.00
# 4513           Misc  Microsoft Game Studios      0.18      0.09      0.14
# 13789  Role-Playing             Square Enix      0.00      0.00      0.04
# 13763      Fighting      Namco Bandai Games      0.03      0.01      0.00
#
#        Other_Sales  Global_Sales
# 8293          0.00          0.17
# ...

# %%
vgSalesData.info() #inspect type of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### This data set has 16598 entries data

# %%
sns.catplot(data = vgSalesData, y="Year", kind="violin")
sns.catplot(data = vgSalesData, y="Year", kind="box")

# %% [markdown]
# ### Missing Value checking

# %%
vgSalesData.isna().sum() ## Checking missing or null values each columns
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
vgSalesData[vgSalesData["Year"].isna()] #inspect missing value YEAR
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vgSalesData[vgSalesData["Publisher"].isna()] #inspect missing value PUBLISHER
# Out:
#         Rank                                               Name Platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
#vgSalesData["Year"].fillna(0.0,inplace=True)
#in my opinion: the statistics from .describe() of years will not obvious and it will got outliers with 0.0
vgSalesData["Publisher"].fillna("Unknown",inplace=True)

# %%
vgSalesData.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher         0
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
game = vgSalesData["Name"]

# %%
vg_count = Counter(game)

# %%
vg_count.most_common(10)
# Out:
# [('Need for Speed: Most Wanted', 12),
#  ('FIFA 14', 9),
#  ('Madden NFL 07', 9),
#  ('LEGO Marvel Super Heroes', 9),
#  ('Ratatouille', 9),
#  ('FIFA Soccer 13', 8),
#  ('FIFA 15', 8),
#  ('LEGO Star Wars II: The Original Trilogy', 8),
#  ('Madden NFL 08', 8),
#  ('Monopoly', 8)]

# %% [markdown]
# ### some games have a same name but different platforms

# %%
vgSalesData[vgSalesData.isin(["FIFA 14"])["Name"]] #same game but was published different platform
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 112    113  FIFA 14      PS3  2013.0  Sports  Electronic Arts      0.78
# 256    257  FIFA 14     X360  2013.0  Sports  Electronic Arts      0.92
# 493    494  FIFA 14      PS4  2013.0  Sports  Electronic Arts      0.61
# 1698  1700  FIFA 14     XOne  2013.0  Sports  Electronic Arts      0.41
# 3988  3990  FIFA 14      PSV  2013.0  Sports  Electronic Arts      0.11
# 4503  4505  FIFA 14       PC  2013.0  Sports  Electronic Arts      0.01
# 4538  4540  FIFA 14      Wii  2013.0  Sports  Electronic Arts      0.00
# 6661  6663  FIFA 14      3DS  2013.0  Sports  Electronic Arts      0.00
# 7034  7036  FIFA 14      PSP  2013.0  Sports  Electronic Arts      0.00
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 112       4.32      0.07         1.73          6.90
# 256       2.93      0.01         0.46          4.31
# 493       1.85      0.11         0.33          2.90
# ...

# %%
#example1 = vgSalesData.groupby("Publisher")["Name"].count() #.reset_index()
#type(example1)

# %%
vg_publisher = vgSalesData.groupby("Publisher")["Name"].count().reset_index() ## reset index is add the old index to new column then set the new index

# %%
vg_publisher
# Out:
#                         Publisher  Name
# 0                 10TACLE Studios     3
# 1                      1C Company     3
# 2    20th Century Fox Video Games     5
# 3                          2D Boy     1
# 4                             3DO    36
# ..                            ...   ...
# 573                   id Software     1
# 574               imageepoch Inc.     2
# 575          inXile Entertainment     1
# 576                     mixi, Inc     1
# 577                  responDESIGN     2
#
# [578 rows x 2 columns]

# %%
publisher_Top5 = vg_publisher.sort_values(by = "Name" ,ascending = False).head(5)

# %%
publisher_Top5
# Out:
#                         Publisher  Name
# 138               Electronic Arts  1351
# 21                     Activision   975
# 347            Namco Bandai Games   932
# 525                       Ubisoft   921
# 275  Konami Digital Entertainment   832

# %%
vgSalesData[vgSalesData["Publisher"].isin(["Electronic Arts"])]["Publisher"].count() #Checking
# Out:
# 1351

# %% [markdown]
# ## Question : Top 5 of video game publisher (including same game different platform)

# %%
Top5_Publisher = ["Electronic Arts","Activision","Namco Bandai Games","Ubisoft","Konami Digital Entertainment"]

# %%
data_top5_publisher = vgSalesData[vgSalesData["Publisher"].isin(Top5_Publisher)]

# %%
data_top5_publisher
# Out:
#         Rank                                               Name Platform  \
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# 35        36                         Call of Duty: Black Ops II     X360
# ...      ...                                                ...      ...
# 16558  16561                          Pro Evolution Soccer 2008       PC
# 16567  16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 16584  16587                                   Bust-A-Move 3000       GC
# 16591  16594                                Myst IV: Revelation       PC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ## Visualization

# %%
publisher_5 = sns.countplot(data = data_top5_publisher, y = "Publisher")

# %% [markdown]
# ## Question : Top 5 of video game global sales

# %%
top5_global_sales = vgSalesData.sort_values(by="Global_Sales",ascending = False).head(5)

# %%
top5_global_sales
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ## Visualization

# %%
globalsales_5 = sns.barplot(x="Global_Sales",y="Name", data=top5_global_sales) # in milion
